# %%
#標準寫法
import matplotlib.pyplot as plt

# 1.製作figure
fig = plt.figure()

# 2.在1.的figure上製作一個axes
ax_1 = fig.add_subplot(1, 1, 1)

# 3.將圖的數據儲存在axes中
X = [0, 1, 2]
Y = [3, 4, 5]
ax_1.plot(X, Y)

# 4.顯示圖
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes = figure.add_subplot(1,1,1)
X = [0, 3, 9]
Y = [3, 4, 5]
axes.plot(X,Y,color='green',marker='o',linestyle='dashed',linewidth=2,markersize=12)
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes1 = figure.add_subplot(1, 3, 1)
axes2 = figure.add_subplot(1, 3, 2)
axes3 = figure.add_subplot(1, 3, 3)

axes1.set_title("plot1")
axes2.set_title("plot2")
axes3.set_title("plot3")
plt.show()

# %%
# !pip install wget
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=a633cabe5c5fb9c3b9a87b5a4f3362ea59a6588af7b1398991287ae9b13e091f
#   Stored in directory: /home/vscode/.cache/pip/wheels/01/46/3b/e29ffbe4ebe614ff224bad40fc6a5773a67a163251585a13a9
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
import wget

wget.download("https://github.com/roberthsu2003/machine_learning/raw/refs/heads/main/source_data/ChineseFont.ttf")
# Out:
# 'ChineseFont.ttf'

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes1 = figure.add_subplot(1, 3, 1)
axes2 = figure.add_subplot(1, 3, 2)
axes3 = figure.add_subplot(1, 3, 3)

axes1.set_title("圖表1")
axes2.set_title("圖表2")
axes3.set_title("圖表3")
plt.show()
# Out:
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 22294 (\N{CJK UNIFIED IDEOGRAPH-5716}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 34920 (\N{CJK UNIFIED IDEOGRAPH-8868}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font', family="ChineseFont")

figure = plt.figure()
axes1 = figure.add_subplot(1, 3, 1)
axes2 = figure.add_subplot(1, 3, 2)
axes3 = figure.add_subplot(1, 3, 3)

axes1.set_title("圖表1")
axes2.set_title("圖表2")
axes3.set_title("圖表3")
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font', family="ChineseFont")

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
subjects = list(student1.keys())
stu1_values = list(student1.values())
subjects, stu1_values
# Out:
# (['國文', '英文', '數學', '歷史', '探索'], [78, 80, 92, 75, 85])

# %%
#標準寫法
figure = plt.figure(figsize=(8, 5),dpi=240,facecolor='#cccccc')
axes = figure.add_subplot(1,1,1)
axes.set_title("學生分數")
axes.set_xlabel("科目")
axes.set_ylabel("分數")
axes.plot(subjects,stu1_values,marker='o',linestyle='-.')
plt.show()
plt.close()
