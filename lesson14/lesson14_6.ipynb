# %% [markdown]
# ### 條狀圖

# %%
import matplotlib.pyplot as plt
index = [3, 4, 5, 6, 7]
values = [5000, 6000, 7000, 8000, 9000]
subject = ['apple', 'banana', 'orange', 'tomato', 'guava']
plt.bar(index, values)
plt.xticks(index, subject)
print(plt.xticks())
# Out:
# (array([3, 4, 5, 6, 7]), [Text(3, 0, 'apple'), Text(4, 0, 'banana'), Text(5, 0, 'orange'), Text(6, 0, 'tomato'), Text(7, 0, 'guava')])

# %%
import matplotlib.pyplot as plt
index = [3, 4, 5, 6, 7]
values = [5000, 6000, 7000, 8000, 9000]
subject = ['apple', 'banana', 'orange', 'tomato', 'guava']
plt.bar(index, values)
plt.xticks(index, subject)
print(plt.xticks())
for idx,i in enumerate(index):
    plt.annotate(str(values[idx]),(i-0.2,values[idx]+100))
# Out:
# (array([3, 4, 5, 6, 7]), [Text(3, 0, 'apple'), Text(4, 0, 'banana'), Text(5, 0, 'orange'), Text(6, 0, 'tomato'), Text(7, 0, 'guava')])

# %%
for idx,i in enumerate(index):
    print(i)
    print(idx)
    print("====")
# Out:
# 3
# 0
# ====
# 4
# 1
# ====
# 5
# 2
# ====
# 6
# 3
# ====
# 7
# 4
# ====

# %%
import matplotlib.pyplot as plt
index = [3, 4, 5, 6, 7]
values = [5000, 6000, 7000, 8000, 9000]
subject = ['apple', 'banana', 'orange', 'tomato', 'guava']
plt.bar(index, values)
plt.xticks(index, subject)
print(plt.xticks())
for idx,i in enumerate(index):
    plt.annotate(str(values[idx]),(i-0.2,values[idx]+100))

xmin, xmax, ymin, ymax = plt.axis()
xmin -= 0.2
xmax += 0.2
ymin = 3000
ymax += 1000
plt.axis(xmin=xmin, xmax=xmax, ymin=ymin, ymax=ymax)
# Out:
# (array([3, 4, 5, 6, 7]), [Text(3, 0, 'apple'), Text(4, 0, 'banana'), Text(5, 0, 'orange'), Text(6, 0, 'tomato'), Text(7, 0, 'guava')])
# (2.16, 7.84, 3000.0, 10450.0)

# %%
import matplotlib.pyplot as plt
import numpy as np
index = np.array([3, 4, 5, 6, 7])
values1 = [5000, 6000, 7000, 8000, 9000]
values2 = [3000, 4000, 5000, 6000, 7000]
values3 = [4000, 5000, 6000, 7000, 8000]

subject = ['apple', 'banana', 'orange', 'tomato', 'guava']
plt.bar(index, values1,color='r',width=0.3)
plt.bar(index+0.3, values2,color='b',width=0.3)
plt.bar(index-0.3, values3,color='g',width=0.3)
plt.xticks(index, subject)


xmin, xmax, ymin, ymax = plt.axis()
xmin -= 0.2
xmax += 0.2
ymin = 1000
ymax += 1000
_ = plt.axis(xmin=xmin, xmax=xmax, ymin=ymin, ymax=ymax)

# %%
import matplotlib.pyplot as plt
values = [20, 30, 45, 10]
labels = ['Nokia', 'Samsung', 'Apple', 'Lumia']
colors = ['yellow', 'green', 'red', 'blue']

plt.pie(values,labels=labels,colors=colors,startangle=180,explode=[0.3, 0, 0, 0],shadow=True,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7e10fe7a9a60>,
#   <matplotlib.patches.Wedge at 0x7e10ff1e0c20>,
#   <matplotlib.patches.Wedge at 0x7e10fe7aa8d0>,
#   <matplotlib.patches.Wedge at 0x7e10fe7ab1a0>],
#  [Text(-1.156734275252088, -0.78864809418208, 'Nokia'),
#   Text(0.5500000594609757, -0.9526279098330698, 'Samsung'),
#   Text(0.40187500810664456, 1.0239611700935172, 'Apple'),
#   Text(-1.0511301300928029, 0.3242305500891113, 'Lumia')],
#  [Text(-0.743614891233485, -0.5069880605456228, '19.0%'),
#   Text(0.30000003243325946, -0.5196152235453108, '28.6%'),
#   Text(0.21920454987635155, 0.5585242745964638, '42.9%'),
#   Text(-0.5733437073233469, 0.17685302732133343, '9.5%')])
